# %%
#A1
import librosa
import librosa.display
import matplotlib.pyplot as plt
y, sr = librosa.load('Recording.wav')
plt.figure(figsize=(14, 5))
librosa.display.waveshow(y, sr=sr)
plt.title('Waveform')
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
plt.show()

# %%
#A2
print("Length of the signal:",len(y),"samples")
print("Sampling rate:",sr, "Hz")
print("Magnitude range:",np.min(y),"to", np.max(y))
# Out:
# Length of the signal: 132183 samples
# Sampling rate: 22050 Hz
# Magnitude range: -0.7460044 to 0.6701772

# %%
#A3
import IPython.display as ipd
import matplotlib.pyplot as plt
start = int(1 * sr)
end = int(3 * sr)
segment = y[start:end]
plt.figure(figsize=(10, 5))
plt.plot(segment)
plt.title('Segment Waveform')
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.show()
ipd.Audio(segment, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#A4
segment_1_start = int(1 * sr)
segment_1_end = int(3 * sr)
segment_2_start = int(3 * sr)
segment_2_end = int(5 * sr)
segment_1 = y[segment_1_start:segment_1_end]
segment_2 = y[segment_2_start:segment_2_end]
print("Playing Segment 1:")

plt.figure(figsize=(10, 5))
librosa.display.waveshow(segment_1)
plt.title('Segment-1')
plt.show()
ipd.Audio(segment_1, rate=sr)
# Out:
# Playing Segment 1:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Playing Segment 2:")
plt.figure(figsize=(10, 5))
librosa.display.waveshow(segment_2)
plt.title('Segment-1')
plt.show()
ipd.Audio(segment_2, rate=sr)
# Out:
# Playing Segment 2:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#Sampling rate change

new_sr = 10000
y_resampled = librosa.resample(y, orig_sr=sr, target_sr=new_sr)

print(f"Original Sampling Rate: {sr} Hz")
ipd.display(ipd.Audio(y, rate=sr))

print(f"Resampled Sampling Rate: {new_sr} Hz")
ipd.display(ipd.Audio(y_resampled, rate=new_sr))
# Out:
# Original Sampling Rate: 22050 Hz
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Resampled Sampling Rate: 10000 Hz
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
